# %% [markdown]
# # **Simple Data Exploration - Working with the Pandas Library**
#
# **Objective**
#
# How to create dataframe for simple analysis

# %%
import pandas as pd

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}

# %%
purchases = pd.DataFrame(data)
purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
purchases = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])
purchases
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
purchases.loc['June']

# %%
# Method 1 - file upload directly from your computer
# It will prompt you to select a file. Click on “Choose Files” then select and 
# upload the file. Wait for the file to be 100% uploaded.
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd23623f-7911-4261-8590-8d0367d24f38" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd23623f-7911-4261-8590-8d0367d24f38">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Method 2 - file saved online and retrieved online
# Same this file locally 
# Find the folder icon on the left frame
# Select upload - and source the 'purchases.csv' file
# Once uploaded - using the right hand button - select copy path
# Paste the path between the quotes below


df = pd.read_csv('purchases.csv')
df
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2
